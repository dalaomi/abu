# %% [markdown]
# ### 点击上方的运行按钮，启动回测操作界面，如下图所示：
#
# ![](./run_cell.png)

# %%
# %matplotlib inline
import widget_loop_back
widget_loop_back.show_ui()
# Out:
# VBox(children=(Tab(children=(VBox(children=(BoundedIntText(value=1000000, description='初始资金:', max=999999999, …
# 提示
# 动态双均慢动态快动态买入策略已添加成功！
# 提示
# 动态双均慢60快5卖出策略已添加成功！
# Box(children=(Text(value='pid=1035 begin work'), FloatProgress(value=0.0)))
# FloatProgress(value=0.0)
# 买入后卖出的交易数量:4
# 买入后尚未卖出的交易数量:1
# 胜率:25.0000%
# 平均获利期望:4.5758%
# 平均亏损期望:-7.5757%
# 盈亏比:0.2023
# 策略收益: -11.4595%
# 基准收益: 1.8196%
# 策略年化收益: -5.7297%
# 基准年化收益: 0.9098%
# 策略买入成交比例:100.0000%
# 策略资金利用率比例:21.2410%
# 策略共执行504个交易日
# 交易买卖详情单：
#             buy_date  buy_price  buy_cnt                       buy_factor  \
# 2014-11-18  20141118    257.750   2909.0    AbuDoubleMaBuy:fast=8,slow=50
# 2015-04-30  20150430    229.030   3274.0  AbuDoubleMaBuy:fast=30,slow=100
# 2015-09-18  20150918    260.660   2829.0   AbuDoubleMaBuy:fast=5,slow=100
# 2015-12-21  20151221    233.455   3212.0   AbuDoubleMaBuy:fast=24,slow=80
# 2016-06-01  20160601    219.645   3414.0    AbuDoubleMaBuy:fast=4,slow=25
#
#             symbol         buy_pos buy_type_str  expect_direction  \
# 2014-11-18  usTSLA  AbuAtrPosition         call               1.0
# 2015-04-30  usTSLA  AbuAtrPosition         call               1.0
# 2015-09-18  usTSLA  AbuAtrPosition         call               1.0
# 2015-12-21  usTSLA  AbuAtrPosition         call               1.0
# 2016-06-01  usTSLA  AbuAtrPosition         call               1.0
#
#                sell_type_extra  sell_date  sell_price sell_type ml_features  \
# 2014-11-18  AbuDoubleMaSell:61   20141124     244.120      loss        None
# 2015-04-30  AbuDoubleMaSell:61   20150810     239.510       win        None
# 2015-09-18  AbuDoubleMaSell:61   20151001     242.815      loss        None
# 2015-12-21  AbuDoubleMaSell:61   20160111     208.725      loss        None
# 2016-06-01                              0         NaN      keep        None
#
#             key    profit  result  profit_cg  profit_cg_hunder  keep_days
# 2014-11-18   83 -39649.67      -1    -0.0529           -5.2881          6
# 2015-04-30  194  34311.52       1     0.0458            4.5758        102
# 2015-09-18  291 -50483.50      -1    -0.0685           -6.8461         13
# 2015-12-21  356 -79432.76      -1    -0.1059          -10.5930         21
# 2016-06-01  467       NaN       0        NaN               NaN        916

# %% [markdown]
# [abu量化系统github地址](https://github.com/bbfamily/abu) (您的star是我的动力！)
#
# [更多阿布量化量化技术文章](http://www.abuquant.com/article)
#
# 更多关于量化交易相关请阅读[《量化交易之路》](http://www.abuquant.com/books/quantify-trading-road.html)
#
# 更多关于量化交易与机器学习相关请阅读[《机器学习之路》](http://www.abuquant.com/books/machine-learning-road.html)
#
# 更多关于abu量化系统请关注微信公众号: abu_quant
#
# ![](../abupy_lecture/image/qrcode.jpg)
